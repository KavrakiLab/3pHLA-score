# %% [markdown]
# # Validation Dataset 2 - independent validation dataset on non-APE-Gen modeled structures
#
# This is the dataset used for external validation for A0201 allele. Previously used in Antunes et al 2020.

# %%
import pandas as pd

ds = pd.read_csv("./source_data/HLAArena_dataset.csv")
ds = ds[["pdb_code", "complex_number", "alt_conf", "fname", "peptide", "resolution", "BA"]]
#remove phosphorilated peptide
ds = ds[~ ds["peptide"].isin(["RQASIELPSM + PHOS(S4)"])]
ds.to_csv("dataset3.csv", index=False)
ds
# Out:
#    pdb_code  complex_number alt_conf                fname    peptide  \
# 0      3QFD               2        b  3QFD-2b_complex.pdb  AAGIGILTV
# 2      4E5X               1        a   4E5X-1_complex.pdb  LLFGYPVYV
# 3      2X4U               2        a   2X4U-2_complex.pdb  ILKEPVHGV
# 4      2AV1               2        a   2AV1-2_complex.pdb  LLFGYPVYV
# 5      5IRO               2        a  5IRO-2O_complex.pdb  LLFGYPVYV
# ..      ...             ...      ...                  ...        ...
# 78     5IRO               6        a  5IRO-6O_complex.pdb  LLFGYPVYV
# 79     2GUO               1        a   2GUO-1_complex.pdb  AAGIGILTV
# 80     5IRO               1        a  5IRO-1O_complex.pdb  LLFGYPVYV
# 81     2P5W               1        a   2P5W-1_complex.pdb  SLLMWITQC
# 82     2F54               1        a   2F54-1_complex.pdb  SLLMWITQC
#
#    resolution     BA
# 0        1.68    395
# 2        1.95    3.8
# 3         2.1  192.3
# 4        1.95    3.8
# 5        2.64    3.8
# ...
